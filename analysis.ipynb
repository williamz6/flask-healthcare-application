# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load csv
df = pd.read_csv('survey_data.csv')

# %%
df.head()
# Out:
#    age gender  total_income  utilities  entertainment  school_fees  shopping  \
# 0   20   Male      200000.0    10000.0         5000.0          0.0   20000.0
# 1   30   Male      600000.0    50000.0        25000.0          0.0   50000.0
# 2   25   Male      400000.0        0.0            0.0     250000.0   25000.0
#
#    healthcare
# 0      7500.0
# 1     17000.0
# 2     17000.0

# %% [markdown]
# ##  Visualization 1: Ages with the highest income

# %%
age_income = df.groupby('age')['total_income'].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
age_income.plot(kind='bar')
plt.title('Average Income by Age')
plt.xlabel('Age')
plt.ylabel('Average Income ($)')
plt.savefig('charts/age_income.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2. Gender Distribution Across Spending Categories

# %%
gender_spending = df.groupby('gender')[['utilities', 'entertainment', 'school_fees', 'shopping', 'healthcare']].mean()

plt.figure(figsize=(14, 8))
gender_spending.plot(kind='bar')
plt.title('Average Spending by Gender Across Categories')
plt.xlabel('Gender')
plt.ylabel('Average Spending ($)')
plt.savefig('charts/gender_spending.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Additional Analysis: healthcare Spending by Age

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['age'], df['healthcare'], alpha=0.6, color='green')
plt.title('Healthcare Spending by Age')
plt.xlabel('Age')
plt.ylabel('Healthcare Spending ($)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig('charts/healthcare_age_scatter.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(12, 6))
#       2 plt.scatter(df['age'], df['healthcare'], alpha=0.6, color='green')
#       3 plt.title('Healthcare Spending by Age')
#
# NameError: name 'plt' is not defined
